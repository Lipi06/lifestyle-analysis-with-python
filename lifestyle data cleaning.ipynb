# %%
import csv
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data= pd.read_csv("C:/Users/LiPi/Documents/project/healthlifestyle_project/dataset/Sleep_health_and_lifestyle_dataset.csv")

# %%
#understabd the data

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
data.shape
# Out:
# (374, 13)

# %%
data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Person ID                  374
# Gender                       2
# Age                         31
# Occupation                  11
# Sleep Duration              27
# Quality of Sleep             6
# Physical Activity Level     16
# Stress Level                 6
# BMI Category                 4
# Blood Pressure              25
# Heart Rate                  19
# Daily Steps                 20
# Sleep Disorder               3
# dtype: int64

# %%
data['Sleep Disorder'].unique()
# Out:
# array(['None', 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
#cleaning the data

# %%
data.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
data.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
#droping person who has none sleep disorder

# %%
data_new = data[data ['Sleep Disorder'] =!= 'None']

# %%
new_data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# 5            6    Male   28     Software Engineer             5.9
# 6            7    Male   29               Teacher             6.3
# 16          17  Female   29                 Nurse             6.5
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 3                   4                       30             8          Obese
# ...

# %%
#finding the person below 28 have reconrds here

# %%
new_data2 = data[data['Age']< 28]
new_data2
# Out:
#    Person ID Gender  Age         Occupation  Sleep Duration  Quality of Sleep  \
# 0          1   Male   27  Software Engineer             6.1                 6
#
#    Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                       42             6   Overweight         126/83
#
#    Heart Rate  Daily Steps Sleep Disorder
# 0          77         4200           None

# %%
#finding the maximum age record present in the database

# %%
new_data3 = data[data['Age'] > 59]
new_data3
# Out:
# Empty DataFrame
# Columns: [Person ID, Gender, Age, Occupation, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level, BMI Category, Blood Pressure, Heart Rate, Daily Steps, Sleep Disorder]
# Index: []

# %%
data_category = pd.get_dummies(data, columns=['BMI Category' ])
data_category
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level Blood Pressure  \
# 0                   6                       42             6         126/83
# ...

# %%
#scatter plot of physical activity and stress level

# %%
sns.scatterplot(x='Physical Activity Level', y='Stress Level', data=data)
plt.show()
